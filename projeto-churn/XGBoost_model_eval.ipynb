# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1.1 Importar Libs

# %%
# Importação das bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import os
import json
import pickle
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import (classification_report, confusion_matrix, 
                           accuracy_score, precision_score, recall_score, 
                           f1_score, roc_auc_score, roc_curve)
from sklearn.preprocessing import StandardScaler
from scipy.stats import uniform, loguniform, randint
from joblib import dump, load
import warnings


warnings.filterwarnings('ignore')

# Importar funções dos módulos customizados
from ml_utils import evaluate_model, load_and_prepare_datasets, SCORING_METRIC
from search_utils import (plot_search_history, multiple_randomized_search,
                          plot_search_history_from_loaded, 
                          load_search_results, get_best_params_from_saved,
                          save_search_results, save_final_results, 
                          DEFAULT_CV_STRATEGY, MODELS_FOLDER, RESULTS_FOLDER, SEARCHES_FOLDER)
try:
    import xgboost as xgb
except:
    print("❌ XGBoost não encontrado. Instale com: pip install xgboost")

# Configurações de plotagem
plt.rcParams['figure.figsize'] = [12, 8]
sns.set_style("whitegrid")

print("Bibliotecas importadas com sucesso!")
print(f"Pandas: {pd.__version__}")
print(f"NumPy: {np.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"XGBoost: {xgb.__version__}")
# Out:
# Bibliotecas importadas com sucesso!
# Pandas: 2.3.3
# NumPy: 2.3.5
# Scikit-learn: 1.7.2
# XGBoost: 3.1.2

# %% [markdown]
# ### 1.2 Configuração do Modelo

# %%
# Configuração do modelo e hiperparâmetros
MODEL_NAME = "XGBoost"
MODEL_CLASS = xgb.XGBClassifier
RANDOM_STATE_MODEL = 42
RANDOM_STATE_SAMPLE = 10

# Configuração da busca de hiperparâmetros
N_SEARCHES = 20
N_ITER_PER_SEARCH = 5
SAMPLE_SIZE = 0.05  # % of training data for hyperparameter search

print(f"Modelo configurado: {MODEL_NAME}")
print(f"Buscas: {N_SEARCHES} x {N_ITER_PER_SEARCH} iterações")
# Out:
# Modelo configurado: XGBoost
# Buscas: 20 x 5 iterações

# %% [markdown]
# ## 2. Carregamento e Preparação dos Dados

# %%
# Carregamento e preparação inicial dos dados
print("=== CARREGAMENTO DOS DATASETS ===")

# Carregar e preparar datasets usando função do módulo
X_train, X_test, y_train, y_test, X_train_scaled, X_test_scaled, train_data, test_data, scaler = load_and_prepare_datasets()

print(f"Dataset de treino: {train_data.shape}")
print(f"Dataset de teste: {test_data.shape}")
print(f"Features: {X_train_scaled.shape[1]}")

print("\nDistribuição das classes:")
print("Treino:", y_train.value_counts().to_dict())
print("Teste:", y_test.value_counts().to_dict())

print("\nPrimeiras linhas do dataset de treino:")
# Out:
# === CARREGAMENTO DOS DATASETS ===
# Dataset de treino: (37233, 1825)
# Dataset de teste: (12411, 1825)
# Features: 1824
#
# Distribuição das classes:
# Treino: {1: 7050, 2: 5577, 3: 4282, 4: 3733, 5: 3430, 7: 2895, 6: 2857, 8: 2537, 0: 2533, 9: 2339}
# Teste: {1: 2430, 2: 1790, 3: 1408, 4: 1257, 5: 1203, 6: 995, 7: 912, 8: 815, 0: 813, 9: 788}
#
# Primeiras linhas do dataset de treino:

# %%
train_data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.132290 -0.078874 -0.007970  0.126206 -0.019496  0.049232  0.118899
# 1 -1.261489 -1.223371 -1.000089 -1.225078 -1.232434 -0.959512 -1.124728
# 2 -0.803139 -0.742865 -0.624391 -0.887569 -0.834537 -0.721469 -0.968023
# 3  0.495477  0.708491  0.804662  0.502907  0.720904  0.816273  0.587815
# 4  0.731854  0.843948  0.588933  0.628960  0.746698  0.552313  0.452046
#
#           7         8         9  ...      1815      1816      1817      1818  \
# 0 -0.035883  0.027992  0.031445  ...  1.514577  1.355709  1.418220  1.314246
# 1 -1.226982 -0.848620 -1.207445  ... -1.251411 -1.451988 -1.167611 -1.313675
# 2 -0.922214 -0.717852 -0.951887  ... -1.567787 -1.773163 -1.590253 -1.399433
# 3  0.800239  0.893713  0.593013  ...  0.951751  0.926661  1.139622  0.921222
# 4  0.575681  0.506712  0.329009  ...  0.918366  0.802927  0.817431  0.947489
#
#        1819      1820      1821      1822      1823  digit
# 0  1.393841  1.382280  1.272189  1.350409  1.342505      1
# 1 -1.466612 -1.229501 -1.268458 -1.301135 -1.067532      1
# 2 -1.590376 -1.392650 -1.309864 -1.443503 -1.416043      1
# 3  0.899732  1.112191  0.930080  0.907232  1.048508      2
# 4  0.807747  0.683944  0.860839  0.730585  0.559723      2
#
# [5 rows x 1825 columns]

# %% [markdown]
# ## 3. Sampling para Busca de Hiperparâmetros

# %%
# ======================================================================
# SAMPLING ESTRATIFICADO PARA BUSCA DE HIPERPARÂMETROS
# ======================================================================

print("=== PREPARAÇÃO DE AMOSTRA PARA BUSCA DE HIPERPARÂMETROS ===")

# Amostra estratificada do dataset de treino
_, X_sample, _, y_sample = train_test_split(
    X_train_scaled, y_train, 
    test_size=SAMPLE_SIZE,  
    stratify=y_train,
    random_state=RANDOM_STATE_SAMPLE
)

print(f"Dataset original de treino: {X_train_scaled.shape[0]:,} amostras")
print(f"Amostra para busca de hiperparâmetros: {X_sample.shape[0]:,} amostras")
print(f"Redução: {(1 - X_sample.shape[0]/X_train_scaled.shape[0])*100:.1f}%")

print("\nDistribuição das classes na amostra:")
print("Amostra:", pd.Series(y_sample).value_counts().to_dict())
print("Original:", y_train.value_counts().to_dict())
# Out:
# === PREPARAÇÃO DE AMOSTRA PARA BUSCA DE HIPERPARÂMETROS ===
# Dataset original de treino: 37,233 amostras
# Amostra para busca de hiperparâmetros: 1,862 amostras
# Redução: 95.0%
#
# Distribuição das classes na amostra:
# Amostra: {1: 352, 2: 279, 3: 214, 4: 187, 5: 171, 7: 145, 6: 143, 0: 127, 8: 127, 9: 117}
# Original: {1: 7050, 2: 5577, 3: 4282, 4: 3733, 5: 3430, 7: 2895, 6: 2857, 8: 2537, 0: 2533, 9: 2339}

# %% [markdown]
# ## 4. Definir Estratégia de Validação Cruzada

# %%
# Usar estratégia de CV padrão dos módulos
print(f"Estratégia de CV: {DEFAULT_CV_STRATEGY}")

# %% [markdown]
# ## 5. XGBoost - Busca de Hiperparâmetros

# %% [markdown]
# ### 5.1 Definir Espaço de Hiperparâmetros

# %%
# ======================================================================
# DEFINIÇÃO DO ESPAÇO DE HIPERPARÂMETROS
# ======================================================================

# Definir hiperparâmetros específicos para XGBoost
param_distributions = {
    'n_estimators': randint(100, 250),  # Número de árvores
    'max_depth': randint(5, 40),  # Profundidade máxima das árvores
    'learning_rate': uniform(0.7, 1.5),  # Taxa de aprendizado
    'subsample': uniform(0.4, 0.5),  # Fração das amostras para cada árvore
    'colsample_bytree': uniform(0.3, 0.4),  # Fração das features para cada árvore
    'reg_alpha': uniform(1.5, 1.5),  # Regularização L1
    'reg_lambda': uniform(2, 2.5),  # Regularização L2
    'min_child_weight': randint(4, 20),  # Peso mínimo das folhas 
    'gamma': uniform(0.15, 0.75),  # Redução mínima de perda para split 
}

# %% [markdown]
# ### 5.2 Executar Busca de Hiperparâmetros

# %%
# ======================================================================
# BUSCA DE HIPERPARAMETROS
# ======================================================================

print(f"=== BUSCA DE HIPERPARÂMETROS - {MODEL_NAME} ===")
print(f"Iniciando busca de hiperparâmetros para {MODEL_NAME}...")
print(f"Executando {N_SEARCHES} buscas com {N_ITER_PER_SEARCH} iterações cada...")
print(f"Usando amostra de {X_sample.shape[0]:,} exemplos\n")

# Múltiplas execuções do RandomizedSearchCV
search, all_searches, best_params = multiple_randomized_search(
    estimator=MODEL_CLASS(
        objective='multi:softprob', 
        num_class=10,              
        eval_metric='mlogloss',     
        random_state=RANDOM_STATE_MODEL,
        n_jobs=-1,
        verbosity=0
    ),
    param_distributions=param_distributions,
    X=X_sample,
    y=y_sample,
    cv_strategy=DEFAULT_CV_STRATEGY,
    n_searches=N_SEARCHES,
    n_iter_per_search=N_ITER_PER_SEARCH,
    scoring=SCORING_METRIC,
    n_jobs=-1
)

# Exibir os melhores resultados
print(f"\n--- RESULTADOS {MODEL_NAME} ---")
print("Melhores hiperparâmetros encontrados:")
for param, value in search.best_params_.items():
    print(f"  {param}: {value}")
print(f"\nMelhor F1-Score (CV): {search.best_score_:.4f}")
print(f"Desvio padrão: {search.cv_results_['std_test_score'][search.best_index_]:.4f}")
# Out:
# === BUSCA DE HIPERPARÂMETROS - XGBoost ===
# Iniciando busca de hiperparâmetros para XGBoost...
# Executando 20 buscas com 5 iterações cada...
# Usando amostra de 1,862 exemplos
#
# Executando 20 buscas com 5 iterações cada...
#
# Busca 1/20...
# Melhor score desta busca: 0.4396
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.5353764929244422), 'gamma': np.float64(0.7725637385575413), 'learning_rate': np.float64(0.7388769242636961), 'max_depth': 39, 'min_child_weight': 11, 'n_estimators': 233, 'reg_alpha': np.float64(2.621766640170792), 'reg_lambda': np.float64(2.3485393910162835), 'subsample': np.float64(0.8103815035454902)}
# Melhor score geral até agora: 0.4396
#
# Busca 2/20...
# Melhor score desta busca: 0.3852
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.4693769854511275), 'gamma': np.float64(0.21588096375368013), 'learning_rate': np.float64(1.4755010716790669), 'max_depth': 30, 'min_child_weight': 18, 'n_estimators': 122, 'reg_alpha': np.float64(1.9117831940224885), 'reg_lambda': np.float64(2.3761928080551873), 'subsample': np.float64(0.6956039797689211)}
# Melhor score geral até agora: 0.4396
#
# Busca 3/20...
# Melhor score desta busca: 0.4593
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.3589874495081613), 'gamma': np.float64(0.5165966584378394), 'learning_rate': np.float64(0.7944479842484717), 'max_depth': 17, 'min_child_weight': 8, 'n_estimators': 156, 'reg_alpha': np.float64(1.8070260693157083), 'reg_lambda': np.float64(3.755505867313407), 'subsample': np.float64(0.6452501259807593)}
# Melhor score geral até agora: 0.4593
#
# Busca 4/20...
# Melhor score desta busca: 0.4413
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.39549462802100754), 'gamma': np.float64(0.8806886808016591), 'learning_rate': np.float64(0.8129707026286856), 'max_depth': 20, 'min_child_weight': 13, 'n_estimators': 190, 'reg_alpha': np.float64(2.9870099872880598), 'reg_lambda': np.float64(4.138269137279453), 'subsample': np.float64(0.8560520273943114)}
# Melhor score geral até agora: 0.4593
#
# Busca 5/20...
# Melhor score desta busca: 0.4503
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6056820657902788), 'gamma': np.float64(0.2200897321888805), 'learning_rate': np.float64(0.8779880827516865), 'max_depth': 28, 'min_child_weight': 9, 'n_estimators': 103, 'reg_alpha': np.float64(2.28845549413272), 'reg_lambda': np.float64(3.151214727109382), 'subsample': np.float64(0.7407818151473881)}
# Melhor score geral até agora: 0.4593
#
# Busca 6/20...
# Melhor score desta busca: 0.4204
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.5845933035965584), 'gamma': np.float64(0.8989868333141691), 'learning_rate': np.float64(0.7346193037809661), 'max_depth': 39, 'min_child_weight': 15, 'n_estimators': 186, 'reg_alpha': np.float64(2.0699992332799013), 'reg_lambda': np.float64(3.7118097556041874), 'subsample': np.float64(0.536891478064655)}
# Melhor score geral até agora: 0.4593
#
# Busca 7/20...
# Melhor score desta busca: 0.4606
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.4394078632507553), 'gamma': np.float64(0.4003708797381387), 'learning_rate': np.float64(0.8045857342846285), 'max_depth': 28, 'min_child_weight': 17, 'n_estimators': 200, 'reg_alpha': np.float64(1.676689246781349), 'reg_lambda': np.float64(4.169440373968126), 'subsample': np.float64(0.8982454363469426)}
# Melhor score geral até agora: 0.4606
#
# Busca 8/20...
# Melhor score desta busca: 0.4165
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.4661723087170392), 'gamma': np.float64(0.8156627059370252), 'learning_rate': np.float64(0.7554007659452948), 'max_depth': 31, 'min_child_weight': 5, 'n_estimators': 249, 'reg_alpha': np.float64(1.929973204683609), 'reg_lambda': np.float64(3.6158747693627813), 'subsample': np.float64(0.4601390800258986)}
# Melhor score geral até agora: 0.4606
#
# Busca 9/20...
# Melhor score desta busca: 0.4540
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.42646071775764527), 'gamma': np.float64(0.23311554542776572), 'learning_rate': np.float64(0.7933923758618924), 'max_depth': 32, 'min_child_weight': 16, 'n_estimators': 198, 'reg_alpha': np.float64(1.935581291249549), 'reg_lambda': np.float64(2.1816848557268496), 'subsample': np.float64(0.8197899061862426)}
# Melhor score geral até agora: 0.4606
#
# Busca 10/20...
# Melhor score desta busca: 0.4131
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.35212502855146866), 'gamma': np.float64(0.3895595616095495), 'learning_rate': np.float64(1.6604311650253363), 'max_depth': 37, 'min_child_weight': 18, 'n_estimators': 202, 'reg_alpha': np.float64(2.9885451324203953), 'reg_lambda': np.float64(4.0143641620320825), 'subsample': np.float64(0.8321047230085983)}
# Melhor score geral até agora: 0.4606
#
# Busca 11/20...
# Melhor score desta busca: 0.4444
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6235289061896601), 'gamma': np.float64(0.893841156596837), 'learning_rate': np.float64(0.8231452703613145), 'max_depth': 32, 'min_child_weight': 12, 'n_estimators': 237, 'reg_alpha': np.float64(2.700751228489222), 'reg_lambda': np.float64(3.4004203141449114), 'subsample': np.float64(0.8807620177551941)}
# Melhor score geral até agora: 0.4606
#
# Busca 12/20...
# Melhor score desta busca: 0.4351
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6034509842517533), 'gamma': np.float64(0.3479378127846277), 'learning_rate': np.float64(1.150850254037987), 'max_depth': 14, 'min_child_weight': 8, 'n_estimators': 130, 'reg_alpha': np.float64(2.9532699737740282), 'reg_lambda': np.float64(3.096327102719002), 'subsample': np.float64(0.6977876348441518)}
# Melhor score geral até agora: 0.4606
#
# Busca 13/20...
# Melhor score desta busca: 0.4385
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.5956341973867262), 'gamma': np.float64(0.4988250138138063), 'learning_rate': np.float64(1.0599971297803412), 'max_depth': 35, 'min_child_weight': 9, 'n_estimators': 106, 'reg_alpha': np.float64(2.912883737575206), 'reg_lambda': np.float64(4.483217555759282), 'subsample': np.float64(0.7592798979588532)}
# Melhor score geral até agora: 0.4606
#
# Busca 14/20...
# Melhor score desta busca: 0.4470
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.66157296764556), 'gamma': np.float64(0.5186689936342839), 'learning_rate': np.float64(0.7552536554493378), 'max_depth': 27, 'min_child_weight': 11, 'n_estimators': 206, 'reg_alpha': np.float64(1.6882528173337037), 'reg_lambda': np.float64(2.4791676138494165), 'subsample': np.float64(0.665599039599027)}
# Melhor score geral até agora: 0.4606
#
# Busca 15/20...
# Melhor score desta busca: 0.4250
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.3095283536429145), 'gamma': np.float64(0.8631748865955463), 'learning_rate': np.float64(1.190388092137181), 'max_depth': 20, 'min_child_weight': 17, 'n_estimators': 178, 'reg_alpha': np.float64(1.9280753781644315), 'reg_lambda': np.float64(2.679238028592204), 'subsample': np.float64(0.8974609571552162)}
# Melhor score geral até agora: 0.4606
#
# Busca 16/20...
# Melhor score desta busca: 0.3851
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.5070477712057635), 'gamma': np.float64(0.25018340923605487), 'learning_rate': np.float64(1.435592512698326), 'max_depth': 33, 'min_child_weight': 18, 'n_estimators': 233, 'reg_alpha': np.float64(2.433239294356154), 'reg_lambda': np.float64(2.0016881296235964), 'subsample': np.float64(0.7078590231344251)}
# Melhor score geral até agora: 0.4606
#
# Busca 17/20...
# Melhor score desta busca: 0.4089
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.3939275575077267), 'gamma': np.float64(0.8920026984013387), 'learning_rate': np.float64(1.1768198298205559), 'max_depth': 31, 'min_child_weight': 10, 'n_estimators': 160, 'reg_alpha': np.float64(1.5711972187138141), 'reg_lambda': np.float64(2.5912435141737133), 'subsample': np.float64(0.6944342123834787)}
# Melhor score geral até agora: 0.4606
#
# Busca 18/20...
# Melhor score desta busca: 0.4700
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6297053512265065), 'gamma': np.float64(0.29719953753729855), 'learning_rate': np.float64(0.756914726405786), 'max_depth': 26, 'min_child_weight': 19, 'n_estimators': 160, 'reg_alpha': np.float64(1.9658708802897293), 'reg_lambda': np.float64(4.105127529041915), 'subsample': np.float64(0.8328055672945894)}
# Melhor score geral até agora: 0.4700
#
# Busca 19/20...
# Melhor score desta busca: 0.4514
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.45756804421945796), 'gamma': np.float64(0.5960646051032314), 'learning_rate': np.float64(0.8429706237885018), 'max_depth': 38, 'min_child_weight': 15, 'n_estimators': 157, 'reg_alpha': np.float64(2.501481286392667), 'reg_lambda': np.float64(3.5417990653813956), 'subsample': np.float64(0.8596565211403269)}
# Melhor score geral até agora: 0.4700
#
# Busca 20/20...
# Melhor score desta busca: 0.4540
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.4812713980971651), 'gamma': np.float64(0.3118303248999936), 'learning_rate': np.float64(0.9599270908857264), 'max_depth': 18, 'min_child_weight': 6, 'n_estimators': 109, 'reg_alpha': np.float64(1.6889633200931629), 'reg_lambda': np.float64(3.9637445009762837), 'subsample': np.float64(0.8530112023941936)}
# Melhor score geral até agora: 0.4700
#
# 🎯 Busca completa! Melhor score geral: 0.4700
# Total de configurações testadas: 100
#
# --- RESULTADOS XGBoost ---
# Melhores hiperparâmetros encontrados:
#   colsample_bytree: 0.6297053512265065
#   gamma: 0.29719953753729855
#   learning_rate: 0.756914726405786
#   max_depth: 26
#   min_child_weight: 19
#   n_estimators: 160
#   reg_alpha: 1.9658708802897293
#   reg_lambda: 4.105127529041915
#   subsample: 0.8328055672945894
#
# Melhor F1-Score (CV): 0.4700
# Desvio padrão: 0.0308

# %% [markdown]
# ### 5.3 Visualizar Histórico da Busca

# %%
# Registro de Desempenho - plotar evolução da busca
plot_search_history(all_searches, search, MODEL_NAME)

# %%
# ======================================================================
# ANÁLISE DAS MELHORES CONFIGURAÇÕES ENCONTRADAS
# ======================================================================

print(f"=== MELHORES CONFIGURAÇÕES ENCONTRADAS POR BUSCA - {MODEL_NAME} ===")

# Extrair os melhores resultados de cada busca
best_configs = []

for i, search_result in enumerate(all_searches):
    config = {
        'Busca': i + 1,
        'F1_Score': search_result['best_score'],
        **search_result['best_params']
    }
    best_configs.append(config)

# Criar DataFrame e exibir top configs
results_df = pd.DataFrame(best_configs)
results_df = results_df.sort_values('F1_Score', ascending=False).round(4)

print(f"\nTop configurações (de {len(results_df)} buscas):")
print(results_df.to_string(index=False))

print(f"\nEstatísticas dos F1-Scores encontrados:")
print(f"  Média: {results_df['F1_Score'].mean():.4f}")
print(f"  Mediana: {results_df['F1_Score'].median():.4f}")
print(f"  Desvio padrão: {results_df['F1_Score'].std():.4f}")
print(f"  Min: {results_df['F1_Score'].min():.4f}")
print(f"  Max: {results_df['F1_Score'].max():.4f}")
# Out:
# === MELHORES CONFIGURAÇÕES ENCONTRADAS POR BUSCA - XGBoost ===
#
# Top configurações (de 20 buscas):
#  Busca  F1_Score  colsample_bytree  gamma  learning_rate  max_depth  min_child_weight  n_estimators  reg_alpha  reg_lambda  subsample
#     18    0.4700            0.6297 0.2972         0.7569         26                19           160     1.9659      4.1051     0.8328
#      7    0.4606            0.4394 0.4004         0.8046         28                17           200     1.6767      4.1694     0.8982
#      3    0.4593            0.3590 0.5166         0.7944         17                 8           156     1.8070      3.7555     0.6453
#      9    0.4540            0.4265 0.2331         0.7934         32                16           198     1.9356      2.1817     0.8198
#     20    0.4540            0.4813 0.3118         0.9599         18                 6           109     1.6890      3.9637     0.8530
#     19    0.4514            0.4576 0.5961         0.8430         38                15           157     2.5015      3.5418     0.8597
#      5    0.4503            0.6057 0.2201         0.8780         28                 9           103     2.2885      3.1512     0.7408
#     14    0.4470            0.6616 0.5187         0.7553         27                11           206     1.6883      2.4792     0.6656
#     11    0.4444            0.6235 0.8938         0.8231         32                12           237     2.7008      3.4004     0.8808
#      4    0.4413            0.3955 0.8807         0.8130         20                13           190     2.9870      4.1383     0.8561
#      1    0.4396            0.5354 0.7726         0.7389         39                11           233     2.6218      2.3485     0.8104
#     13    0.4385            0.5956 0.4988         1.0600         35                 9           106     2.9129      4.4832     0.7593
#     12    0.4351            0.6035 0.3479         1.1509         14                 8           130     2.9533      3.0963     0.6978
#     15    0.4250            0.3095 0.8632         1.1904         20                17           178     1.9281      2.6792     0.8975
#      6    0.4204            0.5846 0.8990         0.7346         39                15           186     2.0700      3.7118     0.5369
#      8    0.4165            0.4662 0.8157         0.7554         31                 5           249     1.9300      3.6159     0.4601
#     10    0.4131            0.3521 0.3896         1.6604         37                18           202     2.9885      4.0144     0.8321
#     17    0.4089            0.3939 0.8920         1.1768         31                10           160     1.5712      2.5912     0.6944
#      2    0.3852            0.4694 0.2159         1.4755         30                18           122     1.9118      2.3762     0.6956
#     16    0.3851            0.5070 0.2502         1.4356         33                18           233     2.4332      2.0017     0.7079
#
# Estatísticas dos F1-Scores encontrados:
#   Média: 0.4350
#   Mediana: 0.4405
#   Desvio padrão: 0.0238
#   Min: 0.3851
#   Max: 0.4700

# %% [markdown]
# ## 6. Salvar Resultados de Busca

# %%
search_df = save_search_results(
    model_name=MODEL_NAME,
    model_search=search,
    model_all_searches=all_searches,
    n_searches=N_SEARCHES,
    n_iter_per_search=N_ITER_PER_SEARCH,
    scoring=SCORING_METRIC,
    cv_folds=DEFAULT_CV_STRATEGY.get_n_splits(),
    top_params_columns=param_distributions.keys(),
    searches_folder=SEARCHES_FOLDER
)
# Out:
# === SALVANDO RESULTADOS DA BUSCA - XGBOOST ===
#   ✅ Todos os Resultados salvos: searches\xgboost_all_searches.csv
#   Total de configurações testadas: 100
#   ✅ Resumo salvo: searches\xgboost_search_summary.json
#
# --- ESTATÍSTICAS DA BUSCA XGBOOST ---
# Melhor F1-Score: 0.4700
# Desvio padrão do melhor: 0.0308
# F1-Score médio geral: 0.3865
# F1-Score mínimo: 0.2694
# F1-Score máximo: 0.4700

# %% [markdown]
# ### 6.2 Carregar Resultado de Busca (Opcional)

# %%
loaded_results = load_search_results(MODEL_NAME)

# %%
# Plotar a história da busca a partir dos resultados carregados
plot_search_history_from_loaded(loaded_results, MODEL_NAME)

# %% [markdown]
# ### 6.3 Definir Melhores Params e CV score

# %%
# Definir Melhores Parâmetros para Uso Posterior
if 'loaded_results' in locals():
    best_params = get_best_params_from_saved(MODEL_NAME)
    best_score = loaded_results['summary']['best_overall_score']
    print(f"✅ Usando parâmetros carregados: {best_params}")
    print(f"✅ Melhor F1-Score carregado: {best_score:.4f}")
else:
    best_params = search.best_params_
    best_score = search.best_score_
    print(f"✅ Usando parâmetros da busca atual: {best_params}")
    print(f"✅ Melhor F1-Score da busca atual: {best_score:.4f}")
# Out:
# ✅ Usando parâmetros da busca atual: {'colsample_bytree': np.float64(0.6297053512265065), 'gamma': np.float64(0.29719953753729855), 'learning_rate': np.float64(0.756914726405786), 'max_depth': 26, 'min_child_weight': 19, 'n_estimators': 160, 'reg_alpha': np.float64(1.9658708802897293), 'reg_lambda': np.float64(4.105127529041915), 'subsample': np.float64(0.8328055672945894)}
# ✅ Melhor F1-Score da busca atual: 0.4700

# %% [markdown]
# ## 7. Treinar Modelo Final e Salvar

# %%
# Treinamento Final com melhores hiperparâmetros
best_model = MODEL_CLASS(
    objective='multi:softprob',  # Multiclasse com probabilidades
    num_class=10,  # 10 classes (dígitos 0-9)
    eval_metric='mlogloss',  # Multi-class log loss
    random_state=RANDOM_STATE_MODEL,
    **best_params
)
best_model.fit(X_train_scaled, y_train)
print(f"\nModelo final {MODEL_NAME} treinado com dataset completo: {best_model}")
# Out:
# Modelo final XGBoost treinado com dataset completo: XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=np.float64(0.6297053512265065), device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='mlogloss', feature_types=None, feature_weights=None,
#               gamma=np.float64(0.29719953753729855), grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=np.float64(0.756914726405786), max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=26, max_leaves=None,
#               min_child_weight=19, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=160, n_jobs=None, num_class=10, ...)

# %%
# Save the trained model immediately after training
os.makedirs(MODELS_FOLDER, exist_ok=True)

model_path = os.path.join(MODELS_FOLDER, f'{MODEL_NAME.lower().replace(" ", "_")}_model.joblib')
dump(best_model, model_path)
print(f"✅ Model saved to: {model_path}")
# Out:
# ✅ Model saved to: models\xgboost_model.joblib

# %% [markdown]
# ## 8. Avaliação Final e Salvamento dos Resultados

# %%
# Carregar modelo (Opcional)
loaded_model = load(os.path.join(MODELS_FOLDER, f'{MODEL_NAME.lower().replace(" ", "_")}_model.joblib'))

# %%
print(f"=== AVALIAÇÃO E SALVAMENTO DOS RESULTADOS - {MODEL_NAME} ===")

# Criar pastas se não existirem
os.makedirs(RESULTS_FOLDER, exist_ok=True)

# Avaliação completa do modelo
print("\nAvaliando performance do modelo...")

# Usar datasets completos para avaliação final
X_train_eval = X_train_scaled
y_train_eval = y_train
X_test_eval = X_test_scaled
y_test_eval = y_test

# Avaliar modelo usando função do módulo
train_metrics, test_metrics, y_test_pred = evaluate_model(
    best_model, X_train_eval, X_test_eval, y_train_eval, y_test_eval, MODEL_NAME
)
# Out:
# === AVALIAÇÃO E SALVAMENTO DOS RESULTADOS - XGBoost ===
#
# Avaliando performance do modelo...

# %% [markdown]
# ### 8.3 Save Final Results

# %%
# Plot confusion matrix
cm = confusion_matrix(y_test_eval, y_test_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=True)
plt.title(f'{MODEL_NAME} - Confusion Matrix (Test Set)')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.2 Visualize Confusion Matrix

# %%
print(classification_report(y_test_eval, y_test_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.75      0.75       813
#            1       0.82      0.89      0.85      2430
#            2       0.82      0.84      0.83      1790
#            3       0.76      0.74      0.75      1408
#            4       0.82      0.82      0.82      1257
#            5       0.77      0.76      0.77      1203
#            6       0.75      0.69      0.72       995
#            7       0.81      0.79      0.80       912
#            8       0.71      0.66      0.68       815
#            9       0.75      0.70      0.72       788
#
#     accuracy                           0.79     12411
#    macro avg       0.78      0.76      0.77     12411
# weighted avg       0.79      0.79      0.79     12411

# %% [markdown]
# ### 8.1 Classification Report

# %%
# Salvar resultados finais usando função do módulo
model_final_results = save_final_results(
    model_name=MODEL_NAME,
    best_params=best_params,
    best_score=best_score,
    train_metrics=train_metrics,
    test_metrics=test_metrics,
    y_pred=y_test_pred,
    y_test=y_test_eval,
    X_train_scaled=X_train_eval,
    X_test_scaled=X_test_eval,
    results_folder=RESULTS_FOLDER
)

# Mostrar resumo final
print(f"\n--- RESUMO FINAL {MODEL_NAME} ---")
print(f"F1-Score CV: {model_final_results['best_cv_score']:.4f}")
print(f"F1-Score Teste: {test_metrics['f1']:.4f}")
print(f"Acurácia Teste: {test_metrics['accuracy']:.4f}")
print(f"Precisão Teste: {test_metrics['precision']:.4f}")
print(f"Recall Teste: {test_metrics['recall']:.4f}")
print(f"G-Mean Teste: {test_metrics['gmean']:.4f}")

print(f"Resultados salvos em: {RESULTS_FOLDER}/")
print(f"\nAvaliação do {MODEL_NAME} concluída com sucesso!")
# Out:
# ✅ Resultados XGBoost salvos em: results\xgboost_results.json
#
# --- RESUMO FINAL XGBoost ---
# F1-Score CV: 0.4700
# F1-Score Teste: 0.7702
# Acurácia Teste: 0.7874
# Precisão Teste: 0.7766
# Recall Teste: 0.7647
# G-Mean Teste: 0.7617
# Resultados salvos em: results/
#
# Avaliação do XGBoost concluída com sucesso!
